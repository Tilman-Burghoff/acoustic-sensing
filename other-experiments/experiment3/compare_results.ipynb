# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_outside = pd.read_csv("results_mic_outside.csv")
df_contact0 = pd.read_csv("results_contact_joint0.csv")
df_contact3 = pd.read_csv("results_contact_joint3.csv")
df_EE = pd.read_csv("results_contact_end-effector.csv")

# %%
df_outside[["Position"]] = "Outside"
df_contact0[["Position"]] = "Joint 0"
df_contact3[["Position"]] = "Joint 3"
df_EE[["Position"]] = "End-Effector"

# %%
df = pd.concat([df_outside, df_contact0, df_contact3, df_EE])
# std of error in deg for better readibility
df.loc[df.Metricname == "Standard Deviation of Error", "Result"] = np.rad2deg(df.loc[df.Metricname == "Standard Deviation of Error"].Result)

# %%
ax = sns.barplot(data=df.loc[df.Metricname == "Mean Square Error"], x="Modelname", y="Result", errorbar=("ci", 95), hue="Position")
plt.xticks(rotation=45)
plt.ylabel("Mean Square Error [Rad]")
plt.xlabel("")
plt.title("Mean Square Error")
# Out:
# Text(0.5, 1.0, 'Mean Square Error')

# %%
ax = sns.barplot(data=df.loc[(df.Metricname == "Mean Square Error") & (df.Joint == 0)], x="Modelname", y="Result", errorbar=("ci", 95), hue="Position")
plt.xticks(rotation=45)
plt.ylabel("Mean Square Error [Rad]")
plt.xlabel("")
plt.title("Mean Square Error at joint 0")
#  & ~(df.Modelname == "kNN")
# Out:
# Text(0.5, 1.0, 'Mean Square Error at joint 0')

# %%
ax = sns.barplot(data=df.loc[(df.Metricname == "Mean Square Error") & (df.Joint == 0) & (df.Position.isin(["Outside", "Joint 0"]))], x="Modelname", y="Result", errorbar=("ci", 95), hue="Position")
plt.xticks(rotation=45)
plt.ylabel("Mean Square Error [Rad]")
plt.xlabel("")
plt.title("Mean Square Error at joint 0")
# Out:
# Text(0.5, 1.0, 'Mean Square Error at joint 0')

# %%
ax = sns.barplot(data=df.loc[(df.Metricname == "Mean Square Error") & (df.Joint == 3) ], x="Modelname", y="Result", errorbar=("ci", 95), hue="Position")
plt.xticks(rotation=45)
plt.ylabel("Mean Square Error [Rad]")
plt.xlabel("")
plt.title("Mean Square Error at joint 3")
# & ~(df.Modelname == "kNN")
# Out:
# Text(0.5, 1.0, 'Mean Square Error at joint 3')

# %%
ax = sns.barplot(data=df.loc[(df.Metricname == "Mean Square Error") & (df.Joint == 3) & ~(df.Position == "Joint 0")], x="Modelname", y="Result", errorbar=("ci", 95), hue="Position")
plt.xticks(rotation=45)
plt.ylabel("Mean Square Error [Rad]")
plt.xlabel("")
plt.title("Mean Square Error at joint 3")
# & ~(df.Modelname == "kNN")
# Out:
# Text(0.5, 1.0, 'Mean Square Error at joint 3')

# %%
ax = sns.barplot(data=df.loc[(df.Metricname == "Mean Square Error") ], x="Joint", y="Result", errorbar=("ci", 95), hue="Position")
plt.ylabel("Mean Square Error [Rad]")
plt.xlabel("")
plt.title("Mean Square Error averaged over Models")# (w/o kNN)")
# & ~(df.Modelname == "kNN")
# Out:
# Text(0.5, 1.0, 'Mean Square Error averaged over Models')

# %%
ax = sns.barplot(data=df.loc[(df.Metricname == "Standard Deviation of Error")], x="Modelname", y="Result", errorbar=("ci", 95), hue="Position")
plt.xticks(rotation=45)
plt.ylabel("Standard Deviation [deg]")
plt.xlabel("")
plt.title("Standard Deviation of Error")
# Out:
# Text(0.5, 1.0, 'Standard Deviation of Error')

# %%
ax = sns.barplot(data=df.loc[(df.Metricname == "Standard Deviation of Error") & (df.Joint ==0)], x="Modelname", y="Result", errorbar=("ci", 95), hue="Position")
plt.xticks(rotation=45)
plt.ylabel("Standard Deviation [deg]")
plt.xlabel("")
plt.title("Standard Deviation of Error at Joint 0")
# Out:
# Text(0.5, 1.0, 'Standard Deviation of Error at Joint 0')

# %%
ax = sns.barplot(data=df.loc[(df.Metricname == "Standard Deviation of Error") & (df.Joint ==0)], x="Modelname", y="Result", errorbar=("ci", 95), hue="Position")
plt.xticks(rotation=45)
plt.ylabel("Standard Deviation [deg]")
plt.xlabel("")
plt.title("Standard Deviation of Error at Joint 0")
# Out:
# Text(0.5, 1.0, 'Standard Deviation of Error at Joint 0')

# %%
ax = sns.barplot(data=df.loc[(df.Metricname == "Standard Deviation of Error") & (df.Joint ==3)], x="Modelname", y="Result", errorbar=("ci", 95), hue="Position")
plt.xticks(rotation=45)
plt.ylabel("Standard Deviation [deg]")
plt.xlabel("")
plt.title("Standard Deviation of Error at Joint 3")
# Out:
# Text(0.5, 1.0, 'Standard Deviation of Error at Joint 3')

# %%
ax = sns.barplot(data=df.loc[(df.Metricname == "Standard Deviation of Error")], x="Joint", y="Result", errorbar=("ci", 95), hue="Position")
plt.ylabel("Standard Deviation [deg]")
plt.xlabel("")
plt.title("Standard Deviation of Error averaged over Models")# (w/o kNN)")
# Out:
# Text(0.5, 1.0, 'Standard Deviation of Error averaged over Models')
