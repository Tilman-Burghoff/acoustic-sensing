# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("results_KNN.csv", index_col=0)

# %%
# std of error in deg for better readibility
df.loc[df.Metricname == "Standard Deviation of Error", "Result"] = np.rad2deg(df.loc[df.Metricname == "Standard Deviation of Error"].Result)

# %%
df.loc[df.Result.isna()]
# Out:
# Empty DataFrame
# Columns: [Iteration, Modelname, Metricname, Result]
# Index: []

# %%
tabledata = pd.pivot_table(df, index='Modelname', columns='Metricname', values='Result') # aggregate means

# %%
tabledata.style.apply(lambda col: ['font-weight:bold' if x==col.min() else '' for x in col])
# Out:
# <style type="text/css">
# #T_d42e9_row0_col1, #T_d42e9_row5_col2, #T_d42e9_row7_col0, #T_d42e9_row15_col3, #T_d42e9_row23_col4 {
#   font-weight: bold;
# }
# </style>
# <table id="T_d42e9">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Metricname</th>
#       <th id="T_d42e9_level0_col0" class="col_heading level0 col0" >Mean Square Error</th>
#       <th id="T_d42e9_level0_col1" class="col_heading level0 col1" >R squared</th>
#       <th id="T_d42e9_level0_col2" class="col_heading level0 col2" >Ratio of Outliers (>= 0.5 rad)</th>
#       <th id="T_d42e9_level0_col3" class="col_heading level0 col3" >Standard Deviation of Error</th>
#       <th id="T_d42e9_level0_col4" class="col_heading level0 col4" >Standard deviation per Recording (avg)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Modelname</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d42e9_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_d42e9_row0_col0" class="data row0 col0" >0.137798</td>
#       <td id="T_d42e9_row0_col1" class="data row0 col1" >0.381328</td>
#       <td id="T_d42e9_row0_col2" class="data row0 col2" >0.137235</td>
#       <td id="T_d42e9_row0_col3" class="data row0 col3" >19.346957</td>
#       <td id="T_d42e9_row0_col4" class="data row0 col4" >0.243653</td>
#     </tr>
#     <tr>
#       <th id="T_d42e9_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_d42e9_row1_col0" class="data row1 col0" >0.109318</td>
#       <td id="T_d42e9_row1_col1" class="data row1 col1" >0.506985</td>
#       <td id="T_d42e9_row1_col2" class="data row1 col2" >0.119398</td>
#       <td id="T_d42e9_row1_col3" class="data row1 col3" >16.589155</td>
#       <td id="T_d42e9_row1_col4" class="data row1 col4" >0.189590</td>
#     </tr>
#     <tr>
#       <th id="T_d42e9_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_d42e9_row2_col0" class="data row2 col0" >0.100402</td>
#       <td id="T_d42e9_row2_col1" class="data row2 col1" >0.544724</td>
#       <td id="T_d42e9_row2_col2" class="data row2 col2" >0.102564</td>
#       <td id="T_d42e9_row2_col3" class="data row2 col3" >15.541937</td>
#       <td id="T_d42e9_row2_col4" class="data row2 col4" >0.165593</td>
#     </tr>
#     <tr>
#       <th id="T_d42e9_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_d42e9_row3_col0" class="data row3 col0" >0.095279</td>
#       <td id="T_d42e9_row3_col1" class="data row3 col1" >0.567657</td>
#       <td id="T_d42e9_row3_col2" class="data row3 col2" >0.099777</td>
#       <td id="T_d42e9_row3_col3" class="data row3 col3" >14.911082</td>
#       <td id="T_d42e9_row3_col4" class="data row3 col4" >0.151224</td>
#     </tr>
#     <tr>
#       <th id="T_d42e9_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_d42e9_row4_col0" class="data row4 col0" >0.092888</td>
#       <td id="T_d42e9_row4_col1" class="data row4 col1" >0.577662</td>
#       <td id="T_d42e9_row4_col2" class="data row4 col2" >0.097436</td>
#       <td id="T_d42e9_row4_col3" class="data row4 col3" >14.575763</td>
#       <td id="T_d42e9_row4_col4" class="data row4 col4" >0.140474</td>
#     </tr>
#     <tr>
#       <th id="T_d42e9_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_d42e9_row5_col0" class="data row5 col0" >0.091440</td>
#       <td id="T_d42e9_row5_col1" class="data row5 col1" >0.584353</td>
#       <td id="T_d42e9_row5_col2" class="data row5 col2" >0.095318</td>
#       <td id="T_d42e9_row5_col3" class="data row5 col3" >14.354851</td>
#       <td id="T_d42e9_row5_col4" class="data row5 col4" >0.133355</td>
#     </tr>
#     <tr>
#       <th id="T_d42e9_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_d42e9_row6_col0" class="data row6 col0" >0.091481</td>
#       <td id="T_d42e9_row6_col1" class="data row6 col1" >0.584597</td>
#       <td id="T_d42e9_row6_col2" class="data row6 col2" >0.096433</td>
#       <td id="T_d42e9_row6_col3" class="data row6 col3" >14.252418</td>
#       <td id="T_d42e9_row6_col4" class="data row6 col4" >0.128358</td>
#     </tr>
#     <tr>
#       <th id="T_d42e9_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_d42e9_row7_col0" class="data row7 col0" >0.091423</td>
#       <td id="T_d42e9_row7_col1" class="data row7 col1" >0.585717</td>
#       <td id="T_d42e9_row7_col2" class="data row7 col2" >0.096767</td>
#       <td id="T_d42e9_row7_col3" class="data row7 col3" >14.176376</td>
#       <td id="T_d42e9_row7_col4" class="data row7 col4" >0.124578</td>
#     </tr>
#     <tr>
#       <th id="T_d42e9_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_d42e9_row8_col0" class="data row8 col0" >0.091481</td>
#       <td id="T_d42e9_row8_col1" class="data row8 col1" >0.585998</td>
#       <td id="T_d42e9_row8_col2" class="data row8 col2" >0.096098</td>
#       <td id="T_d42e9_row8_col3" class="data row8 col3" >14.113764</td>
#       <td id="T_d42e9_row8_col4" class="data row8 col4" >0.121409</td>
#     </tr>
#     <tr>
#       <th id="T_d42e9_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_d42e9_row9_col0" class="data row9 col0" >0.091576</td>
#       <td id="T_d42e9_row9_col1" class="data row9 col1" >0.585562</td>
#       <td id="T_d42e9_row9_col2" class="data row9 col2" >0.096210</td>
#       <td id="T_d42e9_row9_col3" class="data row9 col3" >14.078479</td>
#       <td id="T_d42e9_row9_col4" class="data row9 col4" >0.118382</td>
#     </tr>
#     <tr>
#       <th id="T_d42e9_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_d42e9_row10_col0" class="data row10 col0" >0.091764</td>
#       <td id="T_d42e9_row10_col1" class="data row10 col1" >0.584424</td>
#       <td id="T_d42e9_row10_col2" class="data row10 col2" >0.095541</td>
#       <td id="T_d42e9_row10_col3" class="data row10 col3" >14.067255</td>
#       <td id="T_d42e9_row10_col4" class="data row10 col4" >0.116296</td>
#     </tr>
#     <tr>
#       <th id="T_d42e9_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_d42e9_row11_col0" class="data row11 col0" >0.092242</td>
#       <td id="T_d42e9_row11_col1" class="data row11 col1" >0.582473</td>
#       <td id="T_d42e9_row11_col2" class="data row11 col2" >0.095318</td>
#       <td id="T_d42e9_row11_col3" class="data row11 col3" >14.076850</td>
#       <td id="T_d42e9_row11_col4" class="data row11 col4" >0.114521</td>
#     </tr>
#     <tr>
#       <th id="T_d42e9_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_d42e9_row12_col0" class="data row12 col0" >0.092786</td>
#       <td id="T_d42e9_row12_col1" class="data row12 col1" >0.580369</td>
#       <td id="T_d42e9_row12_col2" class="data row12 col2" >0.096210</td>
#       <td id="T_d42e9_row12_col3" class="data row12 col3" >14.093518</td>
#       <td id="T_d42e9_row12_col4" class="data row12 col4" >0.112693</td>
#     </tr>
#     <tr>
#       <th id="T_d42e9_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_d42e9_row13_col0" class="data row13 col0" >0.093151</td>
#       <td id="T_d42e9_row13_col1" class="data row13 col1" >0.578720</td>
#       <td id="T_d42e9_row13_col2" class="data row13 col2" >0.096321</td>
#       <td id="T_d42e9_row13_col3" class="data row13 col3" >14.091115</td>
#       <td id="T_d42e9_row13_col4" class="data row13 col4" >0.111042</td>
#     </tr>
#     <tr>
#       <th id="T_d42e9_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_d42e9_row14_col0" class="data row14 col0" >0.093439</td>
#       <td id="T_d42e9_row14_col1" class="data row14 col1" >0.577510</td>
#       <td id="T_d42e9_row14_col2" class="data row14 col2" >0.097101</td>
#       <td id="T_d42e9_row14_col3" class="data row14 col3" >14.079425</td>
#       <td id="T_d42e9_row14_col4" class="data row14 col4" >0.109390</td>
#     </tr>
#     <tr>
#       <th id="T_d42e9_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_d42e9_row15_col0" class="d

# %%
ax = sns.barplot(data=df.loc[df.Metricname == "Mean Square Error"], x="Modelname", y="Result", errorbar=("ci", 95))
plt.xticks(rotation=45)
plt.ylabel("Mean Square Error [Rad]")
plt.xlabel("")
plt.title("Mean Square Error")
# Out:
# Text(0.5, 1.0, 'Mean Square Error')

# %%
# df.loc[df.Metricname == "Standard Deviation of Error", "Result"] = np.rad2deg(df.loc[df.Metricname == "Standard Deviation of Error"].Result)

ax = sns.barplot(data=df.loc[df.Metricname == "Standard Deviation of Error"], x="Modelname", y="Result", errorbar=("ci", 95))
plt.xticks(rotation=45)
plt.ylabel("Standard Deviation [deg]")
plt.xlabel("")
plt.title("Standard Deviation of Error")
# Out:
# Text(0.5, 1.0, 'Standard Deviation of Error')

# %%
ax = sns.barplot(data=df.loc[df.Metricname == "Standard deviation per Recording (avg)"], x="Modelname", y="Result", errorbar=("ci", 95))
plt.xticks(rotation=45)
plt.ylabel("Standard Deviation [rad]")
plt.xlabel("")
plt.title("Standard Deviation per Recording averaged")
# Out:
# Text(0.5, 1.0, 'Standard Deviation per Recording averaged')

# %%
ax = sns.barplot(data=df.loc[df.Metricname == "R squared"], x="Modelname", y="Result", errorbar=("ci", 95))
plt.xticks(rotation=45)
plt.ylabel("R squared")
plt.xlabel("")
plt.title("R squared")
# Out:
# Text(0.5, 1.0, 'R squared')

# %%
ax = sns.barplot(data=df.loc[df.Metricname == "Ratio of Outliers (>= 0.5 rad)"], x="Modelname", y="Result", errorbar=("ci", 95))
plt.xticks(rotation=45)
plt.ylabel("Ratio of Outliers (Error >= 0.5 rad)")
plt.xlabel("")
plt.title("Ratio of Outliers (Error >= 0.5 rad)")
# Out:
# Text(0.5, 1.0, 'Ratio of Outliers (Error >= 0.5 rad)')
