# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("results.csv", index_col=0)

# %%
# std of error in deg for better readibility
df.loc[df.Metricname == "Standard Deviation of Error", "Result"] = np.rad2deg(df.loc[df.Metricname == "Standard Deviation of Error"].Result) 
df.loc[df.Modelname == "4-Layer FC", "Modelname"] = "5-Layer FC"
df.loc[df.Modelname == "3-Layer FC", "Modelname"] = "4-Layer FC"
df.loc[df.Modelname == "2-Layer FC", "Modelname"] = "3-Layer FC"

# %%
tabledata = pd.pivot_table(df, index='Modelname', columns='Metricname', values='Result') # aggregate means
tabledata = tabledata.reindex(['Linear', '2-Layer FC', '3-Layer FC', '4-Layer FC', '1-Channel CNN', '2-Channel CNN',  '3-Channel CNN','4-Channel CNN'])

# %%
tabledata = tabledata.reindex(['Linear', '3-Layer FC', '4-Layer FC', '5-Layer FC', '1-Channel CNN', '2-Channel CNN',  '3-Channel CNN','4-Channel CNN'])

# %%
tabledata.style.apply(lambda col: ['font-weight:bold' if x==col.min() else '' for x in col])
# Out:
# <style type="text/css">
# #T_1812c_row0_col1, #T_1812c_row6_col0, #T_1812c_row6_col3, #T_1812c_row6_col4, #T_1812c_row7_col2 {
#   font-weight: bold;
# }
# </style>
# <table id="T_1812c">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Metricname</th>
#       <th id="T_1812c_level0_col0" class="col_heading level0 col0" >Mean Square Error</th>
#       <th id="T_1812c_level0_col1" class="col_heading level0 col1" >R squared</th>
#       <th id="T_1812c_level0_col2" class="col_heading level0 col2" >Ratio of Outliers (>= 0.5 rad)</th>
#       <th id="T_1812c_level0_col3" class="col_heading level0 col3" >Standard Deviation of Error</th>
#       <th id="T_1812c_level0_col4" class="col_heading level0 col4" >Standard deviation per Recording (avg)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Modelname</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1812c_level0_row0" class="row_heading level0 row0" >Linear</th>
#       <td id="T_1812c_row0_col0" class="data row0 col0" >0.057834</td>
#       <td id="T_1812c_row0_col1" class="data row0 col1" >0.760973</td>
#       <td id="T_1812c_row0_col2" class="data row0 col2" >0.020726</td>
#       <td id="T_1812c_row0_col3" class="data row0 col3" >13.099137</td>
#       <td id="T_1812c_row0_col4" class="data row0 col4" >0.161122</td>
#     </tr>
#     <tr>
#       <th id="T_1812c_level0_row1" class="row_heading level0 row1" >3-Layer FC</th>
#       <td id="T_1812c_row1_col0" class="data row1 col0" >0.042635</td>
#       <td id="T_1812c_row1_col1" class="data row1 col1" >0.827180</td>
#       <td id="T_1812c_row1_col2" class="data row1 col2" >0.009081</td>
#       <td id="T_1812c_row1_col3" class="data row1 col3" >10.453469</td>
#       <td id="T_1812c_row1_col4" class="data row1 col4" >0.121212</td>
#     </tr>
#     <tr>
#       <th id="T_1812c_level0_row2" class="row_heading level0 row2" >4-Layer FC</th>
#       <td id="T_1812c_row2_col0" class="data row2 col0" >0.027016</td>
#       <td id="T_1812c_row2_col1" class="data row2 col1" >0.885133</td>
#       <td id="T_1812c_row2_col2" class="data row2 col2" >0.009615</td>
#       <td id="T_1812c_row2_col3" class="data row2 col3" >9.110201</td>
#       <td id="T_1812c_row2_col4" class="data row2 col4" >0.115492</td>
#     </tr>
#     <tr>
#       <th id="T_1812c_level0_row3" class="row_heading level0 row3" >5-Layer FC</th>
#       <td id="T_1812c_row3_col0" class="data row3 col0" >nan</td>
#       <td id="T_1812c_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_1812c_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_1812c_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_1812c_row3_col4" class="data row3 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_1812c_level0_row4" class="row_heading level0 row4" >1-Channel CNN</th>
#       <td id="T_1812c_row4_col0" class="data row4 col0" >0.042976</td>
#       <td id="T_1812c_row4_col1" class="data row4 col1" >0.820893</td>
#       <td id="T_1812c_row4_col2" class="data row4 col2" >0.017094</td>
#       <td id="T_1812c_row4_col3" class="data row4 col3" >11.043498</td>
#       <td id="T_1812c_row4_col4" class="data row4 col4" >0.143227</td>
#     </tr>
#     <tr>
#       <th id="T_1812c_level0_row5" class="row_heading level0 row5" >2-Channel CNN</th>
#       <td id="T_1812c_row5_col0" class="data row5 col0" >0.028647</td>
#       <td id="T_1812c_row5_col1" class="data row5 col1" >0.880701</td>
#       <td id="T_1812c_row5_col2" class="data row5 col2" >0.008013</td>
#       <td id="T_1812c_row5_col3" class="data row5 col3" >9.145143</td>
#       <td id="T_1812c_row5_col4" class="data row5 col4" >0.115885</td>
#     </tr>
#     <tr>
#       <th id="T_1812c_level0_row6" class="row_heading level0 row6" >3-Channel CNN</th>
#       <td id="T_1812c_row6_col0" class="data row6 col0" >0.022645</td>
#       <td id="T_1812c_row6_col1" class="data row6 col1" >0.901095</td>
#       <td id="T_1812c_row6_col2" class="data row6 col2" >0.008654</td>
#       <td id="T_1812c_row6_col3" class="data row6 col3" >8.352742</td>
#       <td id="T_1812c_row6_col4" class="data row6 col4" >0.110866</td>
#     </tr>
#     <tr>
#       <th id="T_1812c_level0_row7" class="row_heading level0 row7" >4-Channel CNN</th>
#       <td id="T_1812c_row7_col0" class="data row7 col0" >0.032507</td>
#       <td id="T_1812c_row7_col1" class="data row7 col1" >0.869387</td>
#       <td id="T_1812c_row7_col2" class="data row7 col2" >0.005769</td>
#       <td id="T_1812c_row7_col3" class="data row7 col3" >9.213831</td>
#       <td id="T_1812c_row7_col4" class="data row7 col4" >0.115563</td>
#     </tr>
#   </tbody>
# </table>

# %%
ax = sns.barplot(data=df.loc[df.Metricname == "Mean Square Error"], x="Modelname", y="Result", errorbar=("ci", 95))
plt.xticks(rotation=45)
plt.ylabel("Mean Square Error [Rad]")
plt.xlabel("")
plt.title("Mean Square Error")
# Out:
# Text(0.5, 1.0, 'Mean Square Error')

# %%
sns.barplot(df.loc[df.Metricname=="Mean Square Error"], x="Iteration", y="Result", hue="Modelname")
plt.title("Mean Square Error for each Evaluation")
plt.xlabel("Evaluation")
plt.ylabel("Mean Square Error [Rad]")
# Out:
# Text(0, 0.5, 'Mean Square Error [Rad]')

# %%
ax = sns.barplot(data=df.loc[(df.Metricname == "Mean Square Error") & (df.Iteration != 1)], x="Modelname", y="Result", errorbar=("ci", 95))
plt.xticks(rotation=45)
plt.ylabel("Mean Square Error [Rad]")
plt.xlabel("")
plt.title("Mean Square Error without Outlier")
# Out:
# Text(0.5, 1.0, 'Mean Square Error without Outlier')

# %%
# df.loc[df.Metricname == "Standard Deviation of Error", "Result"] = np.rad2deg(df.loc[df.Metricname == "Standard Deviation of Error"].Result)

ax = sns.barplot(data=df.loc[df.Metricname == "Standard Deviation of Error"], x="Modelname", y="Result", errorbar=("ci", 95))
plt.xticks(rotation=45)
plt.ylabel("Standard Deviation [deg]")
plt.xlabel("")
plt.title("Standard Deviation of Error")
# Out:
# Text(0.5, 1.0, 'Standard Deviation of Error')

# %%
ax = sns.barplot(data=df.loc[(df.Metricname == "Standard Deviation of Error") & (df.Iteration != 1)], x="Modelname", y="Result", errorbar=("ci", 95))
plt.xticks(rotation=45)
plt.ylabel("Standard Deviation [deg]")
plt.xlabel("")
plt.title("Standard Deviation of Error without Outlier")
# Out:
# Text(0.5, 1.0, 'Standard Deviation of Error without Outlier')

# %%
ax = sns.barplot(data=df.loc[df.Metricname == "Standard deviation per Recording (avg)"], x="Modelname", y="Result", errorbar=("ci", 95))
plt.xticks(rotation=45)
plt.ylabel("Standard Deviation [rad]")
plt.xlabel("")
plt.title("Standard Deviation per Recording averaged")
# Out:
# Text(0.5, 1.0, 'Standard Deviation per Recording averaged')

# %%
ax = sns.barplot(data=df.loc[(df.Metricname == "Standard deviation per Recording (avg)") & (df.Iteration != 1)], x="Modelname", y="Result", errorbar=("ci", 95))
plt.xticks(rotation=45)
plt.ylabel("Standard Deviation [rad]")
plt.xlabel("")
plt.title("Standard Deviation per Recording averaged without Outlier")
# Out:
# Text(0.5, 1.0, 'Standard Deviation per Recording averaged without Outlier')

# %%
ax = sns.barplot(data=df.loc[df.Metricname == "R squared"], x="Modelname", y="Result", errorbar=("ci", 95))
plt.xticks(rotation=45)
plt.ylabel("R squared")
plt.xlabel("")
plt.title("R squared")
# Out:
# Text(0.5, 1.0, 'R squared')

# %%
ax = sns.barplot(data=df.loc[(df.Metricname == "R squared") & (df.Iteration != 1)], x="Modelname", y="Result", errorbar=("ci", 95))
plt.xticks(rotation=45)
plt.ylabel("R squared")
plt.xlabel("")
plt.title("R squared without Outlier")
# Out:
# Text(0.5, 1.0, 'R squared without Outlier')

# %%
ax = sns.barplot(data=df.loc[df.Metricname == "Ratio of Outliers (>= 0.5 rad)"], x="Modelname", y="Result", errorbar=("ci", 95))
plt.xticks(rotation=45)
plt.ylabel("Ratio of Outliers (Error >= 0.5 rad)")
plt.xlabel("")
plt.title("Ratio of Outliers (Error >= 0.5 rad) without Outlier")
# Out:
# Text(0.5, 1.0, 'Ratio of Outliers (Error >= 0.5 rad) without Outlier')

# %%
ax = sns.barplot(data=df.loc[(df.Metricname == "Ratio of Outliers (>= 0.5 rad)") & (df.Iteration != 1)], x="Modelname", y="Result", errorbar=("ci", 95))
plt.xticks(rotation=45)
plt.ylabel("Ratio of Outliers (Error >= 0.5 rad)")
plt.xlabel("")
plt.title("Ratio of Outliers (Error >= 0.5 rad)")
# Out:
# Text(0.5, 1.0, 'Ratio of Outliers (Error >= 0.5 rad)')
