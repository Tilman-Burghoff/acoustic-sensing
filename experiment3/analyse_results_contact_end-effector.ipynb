# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("results_contact_end-effector.csv")

# %%
# std of error in deg for better readibility
df.loc[df.Metricname == "Standard Deviation of Error", "Result"] = np.rad2deg(df.loc[df.Metricname == "Standard Deviation of Error"].Result)

# %%
df.loc[df.Result.isna()]
# Out:
# Empty DataFrame
# Columns: [Iteration, Modelname, Metricname, Joint, Result]
# Index: []

# %%
np.unique(df.Modelname)
# Out:
# array(['1-Channel CNN', '2-Channel CNN', '3-Channel CNN', '3-Layer FC',
#        '4-Channel CNN', '4-Layer FC', '5-Layer FC', 'Linear', 'kNN'],
#       dtype=object)

# %%
order = ['kNN', 'Linear', '3-Layer FC', '4-Layer FC', '5-Layer FC', '1-Channel CNN', '2-Channel CNN',  '3-Channel CNN','4-Channel CNN']
tabledata = pd.pivot_table(df, index='Modelname', columns=['Metricname', "Joint"], values='Result') # aggregate means
tabledata = tabledata.reindex(order)

# %%
tabledata.style.apply(lambda col: ['font-weight:bold' if x==col.min() else '' for x in col])
# Out:
# <style type="text/css">
# #T_af8f5_row0_col2, #T_af8f5_row0_col3, #T_af8f5_row0_col8, #T_af8f5_row3_col1, #T_af8f5_row8_col0, #T_af8f5_row8_col4, #T_af8f5_row8_col5, #T_af8f5_row8_col6, #T_af8f5_row8_col7, #T_af8f5_row8_col9 {
#   font-weight: bold;
# }
# </style>
# <table id="T_af8f5">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Metricname</th>
#       <th id="T_af8f5_level0_col0" class="col_heading level0 col0" colspan="2">Mean Square Error</th>
#       <th id="T_af8f5_level0_col2" class="col_heading level0 col2" colspan="2">R squared</th>
#       <th id="T_af8f5_level0_col4" class="col_heading level0 col4" colspan="2">Ratio of Outliers (>= 0.5 rad)</th>
#       <th id="T_af8f5_level0_col6" class="col_heading level0 col6" colspan="2">Standard Deviation of Error</th>
#       <th id="T_af8f5_level0_col8" class="col_heading level0 col8" colspan="2">Standard deviation per Recording (avg)</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Joint</th>
#       <th id="T_af8f5_level1_col0" class="col_heading level1 col0" >0</th>
#       <th id="T_af8f5_level1_col1" class="col_heading level1 col1" >3</th>
#       <th id="T_af8f5_level1_col2" class="col_heading level1 col2" >0</th>
#       <th id="T_af8f5_level1_col3" class="col_heading level1 col3" >3</th>
#       <th id="T_af8f5_level1_col4" class="col_heading level1 col4" >0</th>
#       <th id="T_af8f5_level1_col5" class="col_heading level1 col5" >3</th>
#       <th id="T_af8f5_level1_col6" class="col_heading level1 col6" >0</th>
#       <th id="T_af8f5_level1_col7" class="col_heading level1 col7" >3</th>
#       <th id="T_af8f5_level1_col8" class="col_heading level1 col8" >0</th>
#       <th id="T_af8f5_level1_col9" class="col_heading level1 col9" >3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Modelname</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af8f5_level0_row0" class="row_heading level0 row0" >kNN</th>
#       <td id="T_af8f5_row0_col0" class="data row0 col0" >0.865537</td>
#       <td id="T_af8f5_row0_col1" class="data row0 col1" >0.132933</td>
#       <td id="T_af8f5_row0_col2" class="data row0 col2" >-0.023250</td>
#       <td id="T_af8f5_row0_col3" class="data row0 col3" >0.761574</td>
#       <td id="T_af8f5_row0_col4" class="data row0 col4" >0.670074</td>
#       <td id="T_af8f5_row0_col5" class="data row0 col5" >0.178313</td>
#       <td id="T_af8f5_row0_col6" class="data row0 col6" >53.063387</td>
#       <td id="T_af8f5_row0_col7" class="data row0 col7" >18.891606</td>
#       <td id="T_af8f5_row0_col8" class="data row0 col8" >0.294531</td>
#       <td id="T_af8f5_row0_col9" class="data row0 col9" >0.139702</td>
#     </tr>
#     <tr>
#       <th id="T_af8f5_level0_row1" class="row_heading level0 row1" >Linear</th>
#       <td id="T_af8f5_row1_col0" class="data row1 col0" >0.708059</td>
#       <td id="T_af8f5_row1_col1" class="data row1 col1" >0.033779</td>
#       <td id="T_af8f5_row1_col2" class="data row1 col2" >0.162278</td>
#       <td id="T_af8f5_row1_col3" class="data row1 col3" >0.939122</td>
#       <td id="T_af8f5_row1_col4" class="data row1 col4" >0.593743</td>
#       <td id="T_af8f5_row1_col5" class="data row1 col5" >0.007501</td>
#       <td id="T_af8f5_row1_col6" class="data row1 col6" >48.046269</td>
#       <td id="T_af8f5_row1_col7" class="data row1 col7" >10.515345</td>
#       <td id="T_af8f5_row1_col8" class="data row1 col8" >0.411472</td>
#       <td id="T_af8f5_row1_col9" class="data row1 col9" >0.169515</td>
#     </tr>
#     <tr>
#       <th id="T_af8f5_level0_row2" class="row_heading level0 row2" >3-Layer FC</th>
#       <td id="T_af8f5_row2_col0" class="data row2 col0" >0.669746</td>
#       <td id="T_af8f5_row2_col1" class="data row2 col1" >0.025397</td>
#       <td id="T_af8f5_row2_col2" class="data row2 col2" >0.209691</td>
#       <td id="T_af8f5_row2_col3" class="data row2 col3" >0.954219</td>
#       <td id="T_af8f5_row2_col4" class="data row2 col4" >0.558414</td>
#       <td id="T_af8f5_row2_col5" class="data row2 col5" >0.003692</td>
#       <td id="T_af8f5_row2_col6" class="data row2 col6" >46.698084</td>
#       <td id="T_af8f5_row2_col7" class="data row2 col7" >9.087860</td>
#       <td id="T_af8f5_row2_col8" class="data row2 col8" >0.471332</td>
#       <td id="T_af8f5_row2_col9" class="data row2 col9" >0.144475</td>
#     </tr>
#     <tr>
#       <th id="T_af8f5_level0_row3" class="row_heading level0 row3" >4-Layer FC</th>
#       <td id="T_af8f5_row3_col0" class="data row3 col0" >0.651054</td>
#       <td id="T_af8f5_row3_col1" class="data row3 col1" >0.023726</td>
#       <td id="T_af8f5_row3_col2" class="data row3 col2" >0.231069</td>
#       <td id="T_af8f5_row3_col3" class="data row3 col3" >0.957298</td>
#       <td id="T_af8f5_row3_col4" class="data row3 col4" >0.551108</td>
#       <td id="T_af8f5_row3_col5" class="data row3 col5" >0.002954</td>
#       <td id="T_af8f5_row3_col6" class="data row3 col6" >46.073978</td>
#       <td id="T_af8f5_row3_col7" class="data row3 col7" >8.773794</td>
#       <td id="T_af8f5_row3_col8" class="data row3 col8" >0.454418</td>
#       <td id="T_af8f5_row3_col9" class="data row3 col9" >0.129917</td>
#     </tr>
#     <tr>
#       <th id="T_af8f5_level0_row4" class="row_heading level0 row4" >5-Layer FC</th>
#       <td id="T_af8f5_row4_col0" class="data row4 col0" >0.671921</td>
#       <td id="T_af8f5_row4_col1" class="data row4 col1" >0.026334</td>
#       <td id="T_af8f5_row4_col2" class="data row4 col2" >0.205493</td>
#       <td id="T_af8f5_row4_col3" class="data row4 col3" >0.952675</td>
#       <td id="T_af8f5_row4_col4" class="data row4 col4" >0.565799</td>
#       <td id="T_af8f5_row4_col5" class="data row4 col5" >0.003692</td>
#       <td id="T_af8f5_row4_col6" class="data row4 col6" >46.743533</td>
#       <td id="T_af8f5_row4_col7" class="data row4 col7" >9.266773</td>
#       <td id="T_af8f5_row4_col8" class="data row4 col8" >0.400821</td>
#       <td id="T_af8f5_row4_col9" class="data row4 col9" >0.127822</td>
#     </tr>
#     <tr>
#       <th id="T_af8f5_level0_row5" class="row_heading level0 row5" >1-Channel CNN</th>
#       <td id="T_af8f5_row5_col0" class="data row5 col0" >0.616759</td>
#       <td id="T_af8f5_row5_col1" class="data row5 col1" >0.031873</td>
#       <td id="T_af8f5_row5_col2" class="data row5 col2" >0.269568</td>
#       <td id="T_af8f5_row5_col3" class="data row5 col3" >0.942756</td>
#       <td id="T_af8f5_row5_col4" class="data row5 col4" >0.525884</td>
#       <td id="T_af8f5_row5_col5" class="data row5 col5" >0.006685</td>
#       <td id="T_af8f5_row5_col6" class="data row5 col6" >44.662364</td>
#       <td id="T_af8f5_row5_col7" class="data row5 col7" >10.088243</td>
#       <td id="T_af8f5_row5_col8" class="data row5 col8" >0.476733</td>
#       <td id="T_af8f5_row5_col9" class="data row5 col9" >0.159421</td>
#     </tr>
#     <tr>
#       <th id="T_af8f5_level0_row6" class="row_heading level0 row6" >2-Channel CNN</th>
#       <td id="T_af8f5_row6_col0" class="data row6 col0" >0.511072</td>
#       <td id="T_af8f5_row6_col1" class="data row6 col1" >0.045848</td>
#       <td id="T_af8f5_row6_col2" class="data row6 col2" >0.395884</td>
#       <td id="T_af8f5_row6_col3" class="data row6 col3" >0.921923</td>
#       <td id="T_af8f5_row6_col4" class="data row6 col4" >0.457909</td>
#       <td id="T_af8f5_row6_col5" class="data row6 col5" >0.002293</td>
#       <td id="T_af8f5_row6_col6" class="data row6 col6" >40.580254</td>
#       <td id="T_af8f5_row6_col7" class="data row6 col7" >10.325476</td>
#       <td id="T_af8f5_row6_col8" class="data row6 col8" >0.498427</td>
#       <td id="T_af8f5_row6_col9" class="data row6 col9" >0.138555</td>
#     </tr>
#     <tr>
#       <th id="T_af8f5_level0_row7" class="row_heading leve

# %%
ax = sns.barplot(data=df.loc[df.Metricname == "Mean Square Error"], x="Modelname", y="Result", errorbar=("ci", 95), order=order)
plt.xticks(rotation=75)
plt.ylabel("Mean Square Error [Rad]")
plt.xlabel("")
plt.title("Mean Square Error")
# Out:
# Text(0.5, 1.0, 'Mean Square Error')

# %%
ax = sns.barplot(data=df.loc[df.Metricname == "Mean Square Error"], x="Modelname", y="Result", errorbar=("ci", 95), hue="Joint")
plt.xticks(rotation=45)
plt.ylabel("Mean Square Error [Rad]")
plt.xlabel("")
plt.title("Mean Square Error")
# Out:
# Text(0.5, 1.0, 'Mean Square Error')

# %%
# df.loc[df.Metricname == "Standard Deviation of Error", "Result"] = np.rad2deg(df.loc[df.Metricname == "Standard Deviation of Error"].Result)

ax = sns.barplot(data=df.loc[df.Metricname == "Standard Deviation of Error"], x="Modelname", y="Result", errorbar=("ci", 95))
plt.xticks(rotation=45)
plt.ylabel("Standard Deviation [deg]")
plt.xlabel("")
plt.title("Standard Deviation of Error")
# Out:
# Text(0.5, 1.0, 'Standard Deviation of Error')

# %%
# df.loc[df.Metricname == "Standard Deviation of Error", "Result"] = np.rad2deg(df.loc[df.Metricname == "Standard Deviation of Error"].Result)

ax = sns.barplot(data=df.loc[df.Metricname == "Standard Deviation of Error"], x="Modelname", y="Result", errorbar=("ci", 95), hue="Joint")
plt.xticks(rotation=45)
plt.ylabel("Standard Deviation [deg]")
plt.xlabel("")
plt.title("Standard Deviation of Error")
# Out:
# Text(0.5, 1.0, 'Standard Deviation of Error')

# %%
ax = sns.barplot(data=df.loc[df.Metricname == "Standard deviation per Recording (avg)"], x="Modelname", y="Result", errorbar=("ci", 95))
plt.xticks(rotation=45)
plt.ylabel("Standard Deviation [rad]")
plt.xlabel("")
plt.title("Standard Deviation per Recording averaged")
# Out:
# Text(0.5, 1.0, 'Standard Deviation per Recording averaged')

# %%
ax = sns.barplot(data=df.loc[df.Metricname == "Standard deviation per Recording (avg)"], x="Modelname", y="Result", errorbar=("ci", 95), hue="Joint")
plt.xticks(rotation=45)
plt.ylabel("Standard Deviation [rad]")
plt.xlabel("")
plt.title("Standard Deviation per Recording averaged")
# Out:
# Text(0.5, 1.0, 'Standard Deviation per Recording averaged')

# %%
ax = sns.barplot(data=df.loc[df.Metricname == "R squared"], x="Modelname", y="Result", errorbar=("ci", 95))
plt.xticks(rotation=45)
plt.ylabel("R squared")
plt.xlabel("")
plt.title("R squared")
# Out:
# Text(0.5, 1.0, 'R squared')

# %%
ax = sns.barplot(data=df.loc[df.Metricname == "Ratio of Outliers (>= 0.5 rad)"], x="Modelname", y="Result", errorbar=("ci", 95))
plt.xticks(rotation=45)
plt.ylabel("Ratio of Outliers (Error >= 0.5 rad)")
plt.xlabel("")
plt.title("Ratio of Outliers (Error >= 0.5 rad)")
# Out:
# Text(0.5, 1.0, 'Ratio of Outliers (Error >= 0.5 rad)')

# %%
ax = sns.barplot(data=df.loc[df.Metricname == "Ratio of Outliers (>= 0.5 rad)"], x="Modelname", y="Result", errorbar=("ci", 95), hue="Joint")
plt.xticks(rotation=45)
plt.ylabel("Ratio of Outliers (Error >= 0.5 rad)")
plt.xlabel("")
plt.title("Ratio of Outliers (Error >= 0.5 rad)")
# Out:
# Text(0.5, 1.0, 'Ratio of Outliers (Error >= 0.5 rad)')
