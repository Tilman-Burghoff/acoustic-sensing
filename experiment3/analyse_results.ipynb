# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("results.csv")

# %%
# std of error in deg for better readibility
df.loc[df.Metricname == "Standard Deviation of Error", "Result"] = np.rad2deg(df.loc[df.Metricname == "Standard Deviation of Error"].Result)

# %%
df.loc[df.Result.isna()]
# Out:
# Empty DataFrame
# Columns: [Iteration, Modelname, Metricname, Joint, Result]
# Index: []

# %%
tabledata = pd.pivot_table(df, index='Modelname', columns=['Metricname', "Joint"], values='Result') # aggregate means
tabledata = tabledata.reindex(['kNN', 'Linear', 'SVM', '3-Layer FC', '4-Layer FC', '5-Layer FC', '1-Channel CNN', '2-Channel CNN',  '3-Channel CNN','4-Channel CNN'])

# %%
tabledata.style.apply(lambda col: ['font-weight:bold' if x==col.min() else '' for x in col])
# Out:
# <style type="text/css">
# #T_9a44d_row0_col1, #T_9a44d_row5_col4, #T_9a44d_row9_col0, #T_9a44d_row9_col2, #T_9a44d_row9_col3 {
#   font-weight: bold;
# }
# </style>
# <table id="T_9a44d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Metricname</th>
#       <th id="T_9a44d_level0_col0" class="col_heading level0 col0" >Mean Square Error</th>
#       <th id="T_9a44d_level0_col1" class="col_heading level0 col1" >R squared</th>
#       <th id="T_9a44d_level0_col2" class="col_heading level0 col2" >Ratio of Outliers (>= 0.5 rad)</th>
#       <th id="T_9a44d_level0_col3" class="col_heading level0 col3" >Standard Deviation of Error</th>
#       <th id="T_9a44d_level0_col4" class="col_heading level0 col4" >Standard deviation per Recording (avg)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Modelname</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a44d_level0_row0" class="row_heading level0 row0" >kNN</th>
#       <td id="T_9a44d_row0_col0" class="data row0 col0" >0.091576</td>
#       <td id="T_9a44d_row0_col1" class="data row0 col1" >0.585562</td>
#       <td id="T_9a44d_row0_col2" class="data row0 col2" >0.096210</td>
#       <td id="T_9a44d_row0_col3" class="data row0 col3" >14.078479</td>
#       <td id="T_9a44d_row0_col4" class="data row0 col4" >0.118382</td>
#     </tr>
#     <tr>
#       <th id="T_9a44d_level0_row1" class="row_heading level0 row1" >Linear</th>
#       <td id="T_9a44d_row1_col0" class="data row1 col0" >0.045030</td>
#       <td id="T_9a44d_row1_col1" class="data row1 col1" >0.795906</td>
#       <td id="T_9a44d_row1_col2" class="data row1 col2" >0.019287</td>
#       <td id="T_9a44d_row1_col3" class="data row1 col3" >12.057969</td>
#       <td id="T_9a44d_row1_col4" class="data row1 col4" >0.153926</td>
#     </tr>
#     <tr>
#       <th id="T_9a44d_level0_row2" class="row_heading level0 row2" >SVM</th>
#       <td id="T_9a44d_row2_col0" class="data row2 col0" >0.031837</td>
#       <td id="T_9a44d_row2_col1" class="data row2 col1" >0.859803</td>
#       <td id="T_9a44d_row2_col2" class="data row2 col2" >0.011260</td>
#       <td id="T_9a44d_row2_col3" class="data row2 col3" >10.101023</td>
#       <td id="T_9a44d_row2_col4" class="data row2 col4" >0.119311</td>
#     </tr>
#     <tr>
#       <th id="T_9a44d_level0_row3" class="row_heading level0 row3" >3-Layer FC</th>
#       <td id="T_9a44d_row3_col0" class="data row3 col0" >0.025387</td>
#       <td id="T_9a44d_row3_col1" class="data row3 col1" >0.887047</td>
#       <td id="T_9a44d_row3_col2" class="data row3 col2" >0.007023</td>
#       <td id="T_9a44d_row3_col3" class="data row3 col3" >8.989441</td>
#       <td id="T_9a44d_row3_col4" class="data row3 col4" >0.114854</td>
#     </tr>
#     <tr>
#       <th id="T_9a44d_level0_row4" class="row_heading level0 row4" >4-Layer FC</th>
#       <td id="T_9a44d_row4_col0" class="data row4 col0" >0.023688</td>
#       <td id="T_9a44d_row4_col1" class="data row4 col1" >0.894214</td>
#       <td id="T_9a44d_row4_col2" class="data row4 col2" >0.005909</td>
#       <td id="T_9a44d_row4_col3" class="data row4 col3" >8.679804</td>
#       <td id="T_9a44d_row4_col4" class="data row4 col4" >0.104878</td>
#     </tr>
#     <tr>
#       <th id="T_9a44d_level0_row5" class="row_heading level0 row5" >5-Layer FC</th>
#       <td id="T_9a44d_row5_col0" class="data row5 col0" >0.023395</td>
#       <td id="T_9a44d_row5_col1" class="data row5 col1" >0.895387</td>
#       <td id="T_9a44d_row5_col2" class="data row5 col2" >0.005686</td>
#       <td id="T_9a44d_row5_col3" class="data row5 col3" >8.631950</td>
#       <td id="T_9a44d_row5_col4" class="data row5 col4" >0.100680</td>
#     </tr>
#     <tr>
#       <th id="T_9a44d_level0_row6" class="row_heading level0 row6" >1-Channel CNN</th>
#       <td id="T_9a44d_row6_col0" class="data row6 col0" >0.032565</td>
#       <td id="T_9a44d_row6_col1" class="data row6 col1" >0.853471</td>
#       <td id="T_9a44d_row6_col2" class="data row6 col2" >0.016945</td>
#       <td id="T_9a44d_row6_col3" class="data row6 col3" >10.118872</td>
#       <td id="T_9a44d_row6_col4" class="data row6 col4" >0.138021</td>
#     </tr>
#     <tr>
#       <th id="T_9a44d_level0_row7" class="row_heading level0 row7" >2-Channel CNN</th>
#       <td id="T_9a44d_row7_col0" class="data row7 col0" >0.022747</td>
#       <td id="T_9a44d_row7_col1" class="data row7 col1" >0.901077</td>
#       <td id="T_9a44d_row7_col2" class="data row7 col2" >0.006912</td>
#       <td id="T_9a44d_row7_col3" class="data row7 col3" >8.415339</td>
#       <td id="T_9a44d_row7_col4" class="data row7 col4" >0.114956</td>
#     </tr>
#     <tr>
#       <th id="T_9a44d_level0_row8" class="row_heading level0 row8" >3-Channel CNN</th>
#       <td id="T_9a44d_row8_col0" class="data row8 col0" >0.022118</td>
#       <td id="T_9a44d_row8_col1" class="data row8 col1" >0.899960</td>
#       <td id="T_9a44d_row8_col2" class="data row8 col2" >0.006800</td>
#       <td id="T_9a44d_row8_col3" class="data row8 col3" >8.347526</td>
#       <td id="T_9a44d_row8_col4" class="data row8 col4" >0.115025</td>
#     </tr>
#     <tr>
#       <th id="T_9a44d_level0_row9" class="row_heading level0 row9" >4-Channel CNN</th>
#       <td id="T_9a44d_row9_col0" class="data row9 col0" >0.021463</td>
#       <td id="T_9a44d_row9_col1" class="data row9 col1" >0.904009</td>
#       <td id="T_9a44d_row9_col2" class="data row9 col2" >0.005351</td>
#       <td id="T_9a44d_row9_col3" class="data row9 col3" >8.286144</td>
#       <td id="T_9a44d_row9_col4" class="data row9 col4" >0.115222</td>
#     </tr>
#   </tbody>
# </table>

# %%
ax = sns.barplot(data=df.loc[df.Metricname == "Mean Square Error"], x="Modelname", y="Result", errorbar=("ci", 95))
plt.xticks(rotation=45)
plt.ylabel("Mean Square Error [Rad]")
plt.xlabel("")
plt.title("Mean Square Error")
# Out:
# Text(0.5, 1.0, 'Mean Square Error')

# %%
ax = sns.barplot(data=df.loc[df.Metricname == "Mean Square Error"], x="Modelname", y="Result", errorbar=("ci", 95), hue="Joint")
plt.xticks(rotation=45)
plt.ylabel("Mean Square Error [Rad]")
plt.xlabel("")
plt.title("Mean Square Error")
# Out:
# Text(0.5, 1.0, 'Mean Square Error')

# %%
# df.loc[df.Metricname == "Standard Deviation of Error", "Result"] = np.rad2deg(df.loc[df.Metricname == "Standard Deviation of Error"].Result)

ax = sns.barplot(data=df.loc[df.Metricname == "Standard Deviation of Error"], x="Modelname", y="Result", errorbar=("ci", 95))
plt.xticks(rotation=45)
plt.ylabel("Standard Deviation [deg]")
plt.xlabel("")
plt.title("Standard Deviation of Error")
# Out:
# Text(0.5, 1.0, 'Standard Deviation of Error')

# %%
# df.loc[df.Metricname == "Standard Deviation of Error", "Result"] = np.rad2deg(df.loc[df.Metricname == "Standard Deviation of Error"].Result)

ax = sns.barplot(data=df.loc[df.Metricname == "Standard Deviation of Error"], x="Modelname", y="Result", errorbar=("ci", 95), hue="Joint")
plt.xticks(rotation=45)
plt.ylabel("Standard Deviation [deg]")
plt.xlabel("")
plt.title("Standard Deviation of Error")
# Out:
# Text(0.5, 1.0, 'Standard Deviation of Error')

# %%
ax = sns.barplot(data=df.loc[df.Metricname == "Standard deviation per Recording (avg)"], x="Modelname", y="Result", errorbar=("ci", 95))
plt.xticks(rotation=45)
plt.ylabel("Standard Deviation [rad]")
plt.xlabel("")
plt.title("Standard Deviation per Recording averaged")
# Out:
# Text(0.5, 1.0, 'Standard Deviation per Recording averaged')

# %%
ax = sns.barplot(data=df.loc[df.Metricname == "Standard deviation per Recording (avg)"], x="Modelname", y="Result", errorbar=("ci", 95), hue="Joint")
plt.xticks(rotation=45)
plt.ylabel("Standard Deviation [rad]")
plt.xlabel("")
plt.title("Standard Deviation per Recording averaged")
# Out:
# Text(0.5, 1.0, 'Standard Deviation per Recording averaged')

# %%
ax = sns.barplot(data=df.loc[df.Metricname == "R squared"], x="Modelname", y="Result", errorbar=("ci", 95))
plt.xticks(rotation=45)
plt.ylabel("R squared")
plt.xlabel("")
plt.title("R squared")
# Out:
# Text(0.5, 1.0, 'R squared')

# %%
ax = sns.barplot(data=df.loc[df.Metricname == "Ratio of Outliers (>= 0.5 rad)"], x="Modelname", y="Result", errorbar=("ci", 95))
plt.xticks(rotation=45)
plt.ylabel("Ratio of Outliers (Error >= 0.5 rad)")
plt.xlabel("")
plt.title("Ratio of Outliers (Error >= 0.5 rad)")
# Out:
# Text(0.5, 1.0, 'Ratio of Outliers (Error >= 0.5 rad)')

# %%
ax = sns.barplot(data=df.loc[df.Metricname == "Ratio of Outliers (>= 0.5 rad)"], x="Modelname", y="Result", errorbar=("ci", 95), hue="Joint")
plt.xticks(rotation=45)
plt.ylabel("Ratio of Outliers (Error >= 0.5 rad)")
plt.xlabel("")
plt.title("Ratio of Outliers (Error >= 0.5 rad)")
# Out:
# Text(0.5, 1.0, 'Ratio of Outliers (Error >= 0.5 rad)')
